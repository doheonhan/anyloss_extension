# %% [markdown]
# ## Analaysis of results

# %%
import bayesiantests as bt
import matplotlib.pyplot as plt

#https://matplotlib.org/stable/gallery/lines_bars_and_markers/horizontal_barchart_distribution.html
def stacked_bar(results, category_names):
    """
    Parameters
    ----------
    results : dict
        A mapping from question labels to a list of answers per category.
        It is assumed all lists contain the same number of entries and that
        it matches the length of *category_names*.
    category_names : list of str
        The category labels.
    """
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.colormaps['RdYlGn'](
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, label_type='center', color=text_color)
    ax.legend(ncols=len(category_names), bbox_to_anchor=(0, 1),
              loc='upper left', fontsize='small')

    return fig, ax

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('5CV_MLP(WBCE+_SPL+)_102datasets.csv')
df
# Out:
#     Unnamed: 0 Dataset WBCEAL_0.1 WBCEAL_0.3 WBCEAL_0.5 WBCEAL_0.7 WBCEAL_0.9  \
# 0          Acc       D      0.668      0.648      0.668       0.68      0.676
# 1           F1       S     0.6449     0.6154     0.6319     0.6269     0.6087
# 2        Gmean       1     0.6812     0.6532     0.6786     0.6849     0.6735
# 3        B_Acc       C      0.709     0.6837     0.6969     0.6965     0.6837
# 4          Pre       S     0.5302      0.515     0.5358     0.5488     0.5466
# ..         ...     ...        ...        ...        ...        ...        ...
# 810      Gmean     105     0.9618     0.9538     0.9481      0.946     0.9377
# 811      B_Acc       C     0.9618     0.9538     0.9482     0.9465     0.9387
# 812        Pre       S     0.8272     0.8121     0.8286     0.8766     0.9041
# 813        Rec       V     0.9628     0.9504     0.9337     0.9182     0.8959
# 814        Spe     NaN     0.9608     0.9572     0.9626     0.9747     0.9814
#
#     WBCEFL_0.1 WBCEFL_0.3 WBCEFL_0.5  ... SPLGL_0.1 SPLGL_0.3 SPLGL_0.5  \
# 0         0.66      0.644      0.644  ...     0.416     0.584      0.68
# 1       0.6463     0.6176     0.6235  ...    0.4235    0.1059    0.6433
# 2       0.6811     0.6533     0.6558  ...         0         0    0.6907
# 3       0.7052      0.683     0.6854  ...       0.5       0.5    0.7087
# 4       0.5198     0.5091     0.5112  ...     0.288     0.072    0.5466
# ..         ...        ...        ...  ...       ...       ...       ...
# 810     0.9615     0.9539      0.944  ...         0    0.5693    0.9518
# 811     0.9616      0.954     0.9444  ...       0.5    0.7694    0.9519
# 812     0.8208     0.8451     0.8507  ...   0.09726    0.5115     0.749
# 813      0.964     0.9418     0.9207  ...       0.6    0.9771    0.9666
# 814      0.959     0.9662     0.9681  ...       0.4    0.5617    0.9372
#
#     SPLGL_0.7 SPLGL_0.9 SPLBL_0.1 SPLBL_0.3 SPLBL_0.5 SPLBL_0.7 SPLBL_0.9
# 0       0.676     0.676     0.472     0.584     0.584     0.648      0.66
# 1      0.6364     0.628    0.3176    0.1059    0.2392    0.6272    0.6523
# 2      0.6854    0.6802         0         0    0.1323    0.6558    0.6747
# 3      0.7031    0.6983       0.5       0.5    0.5438     0.691    0.7125
# 4      0.5405    0.5433     0.216     0.072     0.172    0.5173     0.522
# ..        ...       ...       ...       ...       ...       ...       ...
# 810    0.9527    0.9535         0    0.5691    0.1897    0.9531    0.9529
# 811    0.9529    0.9537       0.5    0.7692    0.5897    0.9533    0.9531
# 812    0.7387     0.745   0.06474    0.5087    0.2773    0.7379    0.7475
# 813    0.9727    0.9721       0.4    0.9777    0.9926     0.974    0.9696
# 814     0.933    0.9353       0.6    0.5607    0.1868    0.9327    0.9365
#
# [815 rows x 42 columns]

# %%
df.rename(columns={'Unnamed: 0':'Metrics'}, inplace=True)
df
# Out:
#     Metrics Dataset WBCEAL_0.1 WBCEAL_0.3 WBCEAL_0.5 WBCEAL_0.7 WBCEAL_0.9  \
# 0       Acc       D      0.668      0.648      0.668       0.68      0.676
# 1        F1       S     0.6449     0.6154     0.6319     0.6269     0.6087
# 2     Gmean       1     0.6812     0.6532     0.6786     0.6849     0.6735
# 3     B_Acc       C      0.709     0.6837     0.6969     0.6965     0.6837
# 4       Pre       S     0.5302      0.515     0.5358     0.5488     0.5466
# ..      ...     ...        ...        ...        ...        ...        ...
# 810   Gmean     105     0.9618     0.9538     0.9481      0.946     0.9377
# 811   B_Acc       C     0.9618     0.9538     0.9482     0.9465     0.9387
# 812     Pre       S     0.8272     0.8121     0.8286     0.8766     0.9041
# 813     Rec       V     0.9628     0.9504     0.9337     0.9182     0.8959
# 814     Spe     NaN     0.9608     0.9572     0.9626     0.9747     0.9814
#
#     WBCEFL_0.1 WBCEFL_0.3 WBCEFL_0.5  ... SPLGL_0.1 SPLGL_0.3 SPLGL_0.5  \
# 0         0.66      0.644      0.644  ...     0.416     0.584      0.68
# 1       0.6463     0.6176     0.6235  ...    0.4235    0.1059    0.6433
# 2       0.6811     0.6533     0.6558  ...         0         0    0.6907
# 3       0.7052      0.683     0.6854  ...       0.5       0.5    0.7087
# 4       0.5198     0.5091     0.5112  ...     0.288     0.072    0.5466
# ..         ...        ...        ...  ...       ...       ...       ...
# 810     0.9615     0.9539      0.944  ...         0    0.5693    0.9518
# 811     0.9616      0.954     0.9444  ...       0.5    0.7694    0.9519
# 812     0.8208     0.8451     0.8507  ...   0.09726    0.5115     0.749
# 813      0.964     0.9418     0.9207  ...       0.6    0.9771    0.9666
# 814      0.959     0.9662     0.9681  ...       0.4    0.5617    0.9372
#
#     SPLGL_0.7 SPLGL_0.9 SPLBL_0.1 SPLBL_0.3 SPLBL_0.5 SPLBL_0.7 SPLBL_0.9
# 0       0.676     0.676     0.472     0.584     0.584     0.648      0.66
# 1      0.6364     0.628    0.3176    0.1059    0.2392    0.6272    0.6523
# 2      0.6854    0.6802         0         0    0.1323    0.6558    0.6747
# 3      0.7031    0.6983       0.5       0.5    0.5438     0.691    0.7125
# 4      0.5405    0.5433     0.216     0.072     0.172    0.5173     0.522
# ..        ...       ...       ...       ...       ...       ...       ...
# 810    0.9527    0.9535         0    0.5691    0.1897    0.9531    0.9529
# 811    0.9529    0.9537       0.5    0.7692    0.5897    0.9533    0.9531
# 812    0.7387     0.745   0.06474    0.5087    0.2773    0.7379    0.7475
# 813    0.9727    0.9721       0.4    0.9777    0.9926     0.974    0.9696
# 814     0.933    0.9353       0.6    0.5607    0.1868    0.9327    0.9365
#
# [815 rows x 42 columns]

# %%
# # WBCEAL
# df_acc = df[df['Metrics'] == 'Acc']
# df_acc = df_acc.drop('Dataset', axis=1)
# df_acc = df_acc.reset_index(drop=True)
# df_wbceal = df_acc.iloc[:,1:6].astype(float)
# print(len(df_wbceal))

# # Average
# print("==========", "Average", "==========")
# print("WBCEAL_0.1:",np.mean(df_wbceal.iloc[:,0]))
# print("WBCEAL_0.3:",np.mean(df_wbceal.iloc[:,1]))
# print("WBCEAL_0.5:",np.mean(df_wbceal.iloc[:,2]))
# print("WBCEAL_0.7:",np.mean(df_wbceal.iloc[:,3]))
# print("WBCEAL_0.9:",np.mean(df_wbceal.iloc[:,4]))

# # Bayesian Sign Test
# print("============"*3, "Probability", "============"*3)
# rope = r
# baselines = ['WBCEAL_0.1','WBCEAL_0.3','WBCEAL_0.5','WBCEAL_0.7']
# ours = ['WBCEAL_0.9']
# dfs = [df_wbceal]

# comp = []
# basewin = []
# draw = []
# ourswin = []
# z = 0
# for i in range(len(ours)):
#     for j in range(len(baselines)):
# #         print(z)
#         names = (baselines[j],ours[i])
# #         print(names)
#         comp.append(names)
#         X = np.array(dfs[i][[baselines[j],ours[i]]])
#         left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
# #         print(left, within, right)
#         basewin.append(left)
#         draw.append(within)
#         ourswin.append(right)
        
# results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
# results["Basewin_prob"] = basewin
# results["Draw_prob"] = draw
# results["Ourswin_prob"] = ourswin
# results

# %%
r = 0.005

# %%
# WBCEFL
df_f1 = df[df['Metrics'] == 'F1']
df_f1 = df_f1.drop('Dataset', axis=1)
df_f1 = df_f1.reset_index(drop=True)
df_wbcefl = df_f1.iloc[:,6:11].astype(float)
print(len(df_wbcefl))

# Average
print("==========", "Average", "==========")
print("WBCEFL_0.1:",np.mean(df_wbcefl.iloc[:,0]))
print("WBCEFL_0.3:",np.mean(df_wbcefl.iloc[:,1]))
print("WBCEFL_0.5:",np.mean(df_wbcefl.iloc[:,2]))
print("WBCEFL_0.7:",np.mean(df_wbcefl.iloc[:,3]))
print("WBCEFL_0.9:",np.mean(df_wbcefl.iloc[:,4]))

# Bayesian Sign Test
print("============"*3, "Probability", "============"*3)
rope = r
baselines = ['WBCEFL_0.1','WBCEFL_0.3','WBCEFL_0.5','WBCEFL_0.7']
ours = ['WBCEFL_0.9']
dfs = [df_wbcefl]

comp = []
basewin = []
draw = []
ourswin = []
z = 0
for i in range(len(ours)):
    for j in range(len(baselines)):
#         print(z)
        names = (baselines[j],ours[i])
#         print(names)
        comp.append(names)
        X = np.array(dfs[i][[baselines[j],ours[i]]])
        left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
#         print(left, within, right)
        basewin.append(left)
        draw.append(within)
        ourswin.append(right)
        
results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
results["Basewin_prob"] = basewin
results["Draw_prob"] = draw
results["Ourswin_prob"] = ourswin
results
# Out:
# 102
# ========== Average ==========
# WBCEFL_0.1: 0.6588225490196078
# WBCEFL_0.3: 0.6638549019607842
# WBCEFL_0.5: 0.664636274509804
# WBCEFL_0.7: 0.6656235294117647
# WBCEFL_0.9: 0.6666617647058823
# ==================================== Probability ====================================
# P(WBCEFL_0.1 > WBCEFL_0.9) = 0.00356, P(rope) = 0.00778, P(WBCEFL_0.9 > WBCEFL_0.1) = 0.98866
# P(WBCEFL_0.3 > WBCEFL_0.9) = 0.01636, P(rope) = 0.44674, P(WBCEFL_0.9 > WBCEFL_0.3) = 0.5369
# P(WBCEFL_0.5 > WBCEFL_0.9) = 0.0877, P(rope) = 0.66384, P(WBCEFL_0.9 > WBCEFL_0.5) = 0.24846
# P(WBCEFL_0.7 > WBCEFL_0.9) = 0.04762, P(rope) = 0.84356, P(WBCEFL_0.9 > WBCEFL_0.7) = 0.10882
#      Baseline        Ours  Basewin_prob  Draw_prob  Ourswin_prob
# 0  WBCEFL_0.1  WBCEFL_0.9       0.00356    0.00778       0.98866
# 1  WBCEFL_0.3  WBCEFL_0.9       0.01636    0.44674       0.53690
# 2  WBCEFL_0.5  WBCEFL_0.9       0.08770    0.66384       0.24846
# 3  WBCEFL_0.7  WBCEFL_0.9       0.04762    0.84356       0.10882

# %%
# r=0.01 -> 0.9 is chosen (strict)
# r=0.005-> 0.9 is chosen (strict)
# 4=0.001-> 0.7 is chosen (strict)

# %%
# WBCEGL
df_gm = df[df['Metrics'] == 'Gmean']
df_gm = df_gm.drop('Dataset', axis=1)
df_gm = df_gm.reset_index(drop=True)
df_wbcegl = df_gm.iloc[:,11:16].astype(float)
print(len(df_wbcegl))

# Average
print("==========", "Average", "==========")
print("WBCEGL_0.1:",np.mean(df_wbcegl.iloc[:,0]))
print("WBCEGL_0.3:",np.mean(df_wbcegl.iloc[:,1]))
print("WBCEGL_0.5:",np.mean(df_wbcegl.iloc[:,2]))
print("WBCEGL_0.7:",np.mean(df_wbcegl.iloc[:,3]))
print("WBCEGL_0.9:",np.mean(df_wbcegl.iloc[:,4]))

# Bayesian Sign Test
print("============"*3, "Probability", "============"*3)
rope = r
baselines = ['WBCEGL_0.1','WBCEGL_0.5','WBCEGL_0.7','WBCEGL_0.9']
ours = ['WBCEGL_0.3']
dfs = [df_wbcegl]

comp = []
basewin = []
draw = []
ourswin = []
z = 0
for i in range(len(ours)):
    for j in range(len(baselines)):
#         print(z)
        names = (baselines[j],ours[i])
#         print(names)
        comp.append(names)
        X = np.array(dfs[i][[baselines[j],ours[i]]])
        left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
#         print(left, within, right)
        basewin.append(left)
        draw.append(within)
        ourswin.append(right)
        
results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
results["Basewin_prob"] = basewin
results["Draw_prob"] = draw
results["Ourswin_prob"] = ourswin
results
# Out:
# 102
# ========== Average ==========
# WBCEGL_0.1: 0.8091941176470588
# WBCEGL_0.3: 0.8111686274509804
# WBCEGL_0.5: 0.8093578431372551
# WBCEGL_0.7: 0.8078950980392157
# WBCEGL_0.9: 0.8087539215686274
# ==================================== Probability ====================================
# P(WBCEGL_0.1 > WBCEGL_0.3) = 0.00236, P(rope) = 0.99392, P(WBCEGL_0.3 > WBCEGL_0.1) = 0.00372
# P(WBCEGL_0.5 > WBCEGL_0.3) = 0.0004, P(rope) = 0.99308, P(WBCEGL_0.3 > WBCEGL_0.5) = 0.00652
# P(WBCEGL_0.7 > WBCEGL_0.3) = 0.00142, P(rope) = 0.99238, P(WBCEGL_0.3 > WBCEGL_0.7) = 0.0062
# P(WBCEGL_0.9 > WBCEGL_0.3) = 0.00584, P(rope) = 0.96956, P(WBCEGL_0.3 > WBCEGL_0.9) = 0.0246
#      Baseline        Ours  Basewin_prob  Draw_prob  Ourswin_prob
# 0  WBCEGL_0.1  WBCEGL_0.3       0.00236    0.99392       0.00372
# 1  WBCEGL_0.5  WBCEGL_0.3       0.00040    0.99308       0.00652
# 2  WBCEGL_0.7  WBCEGL_0.3       0.00142    0.99238       0.00620
# 3  WBCEGL_0.9  WBCEGL_0.3       0.00584    0.96956       0.02460

# %%
# r=0.01 -> 0.5 is chosen (out of 1, 3, 5, 7, 9)
# r=0.005-> 0.3 is chosen (strict)
# 4=0.001-> 0.3 is chosen (strict)

# %%
# WBCEBL
df_ba = df[df['Metrics'] == 'B_Acc']
df_ba = df_ba.drop('Dataset', axis=1)
df_ba = df_ba.reset_index(drop=True)
df_wbcebl = df_ba.iloc[:,16:21].astype(float)
print(len(df_wbcebl))

# Average
print("==========", "Average", "==========")
print("WBCEBL_0.1:",np.mean(df_wbcebl.iloc[:,0]))
print("WBCEBL_0.3:",np.mean(df_wbcebl.iloc[:,1]))
print("WBCEBL_0.5:",np.mean(df_wbcebl.iloc[:,2]))
print("WBCEBL_0.7:",np.mean(df_wbcebl.iloc[:,3]))
print("WBCEBL_0.9:",np.mean(df_wbcebl.iloc[:,4]))

# Bayesian Sign Test
print("============"*3, "Probability", "============"*3)
rope = r
baselines = ['WBCEBL_0.1','WBCEBL_0.3','WBCEBL_0.7','WBCEBL_0.9']
ours = ['WBCEBL_0.5']
dfs = [df_wbcebl]

comp = []
basewin = []
draw = []
ourswin = []
z = 0
for i in range(len(ours)):
    for j in range(len(baselines)):
#         print(z)
        names = (baselines[j],ours[i])
#         print(names)
        comp.append(names)
        X = np.array(dfs[i][[baselines[j],ours[i]]])
        left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
#         print(left, within, right)
        basewin.append(left)
        draw.append(within)
        ourswin.append(right)
        
results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
results["Basewin_prob"] = basewin
results["Draw_prob"] = draw
results["Ourswin_prob"] = ourswin
results
# Out:
# 102
# ========== Average ==========
# WBCEBL_0.1: 0.8152519607843138
# WBCEBL_0.3: 0.8147127450980394
# WBCEBL_0.5: 0.8152882352941175
# WBCEBL_0.7: 0.8140352941176472
# WBCEBL_0.9: 0.8126725490196078
# ==================================== Probability ====================================
# P(WBCEBL_0.1 > WBCEBL_0.5) = 0.00014, P(rope) = 0.99902, P(WBCEBL_0.5 > WBCEBL_0.1) = 0.00084
# P(WBCEBL_0.3 > WBCEBL_0.5) = 0.00066, P(rope) = 0.99914, P(WBCEBL_0.5 > WBCEBL_0.3) = 0.0002
# P(WBCEBL_0.7 > WBCEBL_0.5) = 0.0, P(rope) = 0.99998, P(WBCEBL_0.5 > WBCEBL_0.7) = 2e-05
# P(WBCEBL_0.9 > WBCEBL_0.5) = 0.00022, P(rope) = 0.9394, P(WBCEBL_0.5 > WBCEBL_0.9) = 0.06038
#      Baseline        Ours  Basewin_prob  Draw_prob  Ourswin_prob
# 0  WBCEBL_0.1  WBCEBL_0.5       0.00014    0.99902       0.00084
# 1  WBCEBL_0.3  WBCEBL_0.5       0.00066    0.99914       0.00020
# 2  WBCEBL_0.7  WBCEBL_0.5       0.00000    0.99998       0.00002
# 3  WBCEBL_0.9  WBCEBL_0.5       0.00022    0.93940       0.06038

# %%
# r=0.01 -> 0.5 is chosen (out of 1, 3, 5, 7, 9)
# r=0.005-> 0.1 is chosen (strict)
# 4=0.001-> 0.1 is chosen (strict)

# %%
# # SPLAL
# df_acc = df[df['Metrics'] == 'Acc']
# df_acc = df_acc.drop('Dataset', axis=1)
# df_acc = df_acc.reset_index(drop=True)
# df_splal = df_acc.iloc[:,21:26].astype(float)
# print(len(df_splal))

# # Average
# print("==========", "Average", "==========")
# print("SPLAL_0.1:",np.mean(df_splal.iloc[:,0]))
# print("SPLAL_0.3:",np.mean(df_splal.iloc[:,1]))
# print("SPLAL_0.5:",np.mean(df_splal.iloc[:,2]))
# print("SPLAL_0.7:",np.mean(df_splal.iloc[:,3]))
# print("SPLAL_0.9:",np.mean(df_splal.iloc[:,4]))

# # Bayesian Sign Test
# print("============"*3, "Probability", "============"*3)
# rope = r
# baselines = ['SPLAL_0.1','SPLAL_0.3','SPLAL_0.5','SPLAL_0.7']
# ours = ['SPLAL_0.9']
# dfs = [df_splal]

# comp = []
# basewin = []
# draw = []
# ourswin = []
# z = 0
# for i in range(len(ours)):
#     for j in range(len(baselines)):
# #         print(z)
#         names = (baselines[j],ours[i])
# #         print(names)
#         comp.append(names)
#         X = np.array(dfs[i][[baselines[j],ours[i]]])
#         left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
# #         print(left, within, right)
#         basewin.append(left)
#         draw.append(within)
#         ourswin.append(right)
        
# results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
# results["Basewin_prob"] = basewin
# results["Draw_prob"] = draw
# results["Ourswin_prob"] = ourswin
# results
# Out:
# 102
# ========== Average ==========
# SPLAL_0.1: 0.5815284313725491
# SPLAL_0.3: 0.7045627450980392
# SPLAL_0.5: 0.8233578431372548
# SPLAL_0.7: 0.8619117647058823
# SPLAL_0.9: 0.8721774509803921
# ==================================== Probability ====================================
# P(SPLAL_0.1 > SPLAL_0.9) = 0.0, P(rope) = 0.0, P(SPLAL_0.9 > SPLAL_0.1) = 1.0
# P(SPLAL_0.3 > SPLAL_0.9) = 0.0, P(rope) = 0.0, P(SPLAL_0.9 > SPLAL_0.3) = 1.0
# P(SPLAL_0.5 > SPLAL_0.9) = 0.0, P(rope) = 0.42084, P(SPLAL_0.9 > SPLAL_0.5) = 0.57916
# P(SPLAL_0.7 > SPLAL_0.9) = 0.0, P(rope) = 0.99988, P(SPLAL_0.9 > SPLAL_0.7) = 0.00012
#     Baseline       Ours  Basewin_prob  Draw_prob  Ourswin_prob
# 0  SPLAL_0.1  SPLAL_0.9           0.0    0.00000       1.00000
# 1  SPLAL_0.3  SPLAL_0.9           0.0    0.00000       1.00000
# 2  SPLAL_0.5  SPLAL_0.9           0.0    0.42084       0.57916
# 3  SPLAL_0.7  SPLAL_0.9           0.0    0.99988       0.00012

# %%
# r=0.01 -> 0.9 is chosen
# r=0.005-> 0.9 is chosen
# 4=0.001-> 0.9 is chosen

# %%
# SPLFL
df_f1 = df[df['Metrics'] == 'F1']
df_f1 = df_f1.drop('Dataset', axis=1)
df_f1 = df_f1.reset_index(drop=True)
df_splfl = df_f1.iloc[:,26:31].astype(float)
print(len(df_splfl))

# Average
print("==========", "Average", "==========")
print("SPLFL_0.1:",np.mean(df_splfl.iloc[:,0]))
print("SPLFL_0.3:",np.mean(df_splfl.iloc[:,1]))
print("SPLFL_0.5:",np.mean(df_splfl.iloc[:,2]))
print("SPLFL_0.7:",np.mean(df_splfl.iloc[:,3]))
print("SPLFL_0.9:",np.mean(df_splfl.iloc[:,4]))

# Bayesian Sign Test
print("============"*3, "Probability", "============"*3)
rope = r
baselines = ['SPLFL_0.1','SPLFL_0.3','SPLFL_0.5','SPLFL_0.7']
ours = ['SPLFL_0.9']
dfs = [df_splfl]

comp = []
basewin = []
draw = []
ourswin = []
z = 0
for i in range(len(ours)):
    for j in range(len(baselines)):
#         print(z)
        names = (baselines[j],ours[i])
#         print(names)
        comp.append(names)
        X = np.array(dfs[i][[baselines[j],ours[i]]])
        left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
#         print(left, within, right)
        basewin.append(left)
        draw.append(within)
        ourswin.append(right)
        
results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
results["Basewin_prob"] = basewin
results["Draw_prob"] = draw
results["Ourswin_prob"] = ourswin
results
# Out:
# 102
# ========== Average ==========
# SPLFL_0.1: 0.25865764705882355
# SPLFL_0.3: 0.47267117647058826
# SPLFL_0.5: 0.47043039215686266
# SPLFL_0.7: 0.5281715686274511
# SPLFL_0.9: 0.6591607843137256
# ==================================== Probability ====================================
# P(SPLFL_0.1 > SPLFL_0.9) = 0.0, P(rope) = 0.0, P(SPLFL_0.9 > SPLFL_0.1) = 1.0
# P(SPLFL_0.3 > SPLFL_0.9) = 0.0, P(rope) = 0.0, P(SPLFL_0.9 > SPLFL_0.3) = 1.0
# P(SPLFL_0.5 > SPLFL_0.9) = 0.0, P(rope) = 0.0, P(SPLFL_0.9 > SPLFL_0.5) = 1.0
# P(SPLFL_0.7 > SPLFL_0.9) = 0.0, P(rope) = 0.0, P(SPLFL_0.9 > SPLFL_0.7) = 1.0
#     Baseline       Ours  Basewin_prob  Draw_prob  Ourswin_prob
# 0  SPLFL_0.1  SPLFL_0.9           0.0        0.0           1.0
# 1  SPLFL_0.3  SPLFL_0.9           0.0        0.0           1.0
# 2  SPLFL_0.5  SPLFL_0.9           0.0        0.0           1.0
# 3  SPLFL_0.7  SPLFL_0.9           0.0        0.0           1.0

# %%
# r=0.01 -> 0.9 is chosen
# r=0.005-> 0.9 is chosen
# 4=0.001-> 0.9 is chosen

# %%
# SPLGL
df_gm = df[df['Metrics'] == 'Gmean']
df_gm = df_gm.drop('Dataset', axis=1)
df_gm = df_gm.reset_index(drop=True)
df_splgl = df_gm.iloc[:,31:36].astype(float)
print(len(df_splgl))

# Average
print("==========", "Average", "==========")
print("SPLGL_0.1:",np.mean(df_splgl.iloc[:,0]))
print("SPLGL_0.3:",np.mean(df_splgl.iloc[:,1]))
print("SPLGL_0.5:",np.mean(df_splgl.iloc[:,2]))
print("SPLGL_0.7:",np.mean(df_splgl.iloc[:,3]))
print("SPLGL_0.9:",np.mean(df_splgl.iloc[:,4]))

# Bayesian Sign Test
print("============"*3, "Probability", "============"*3)
rope = r
baselines = ['SPLGL_0.1','SPLGL_0.3','SPLGL_0.5','SPLGL_0.7']
ours = ['SPLGL_0.9']
dfs = [df_splgl]

comp = []
basewin = []
draw = []
ourswin = []
z = 0
for i in range(len(ours)):
    for j in range(len(baselines)):
#         print(z)
        names = (baselines[j],ours[i])
#         print(names)
        comp.append(names)
        X = np.array(dfs[i][[baselines[j],ours[i]]])
        left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
#         print(left, within, right)
        basewin.append(left)
        draw.append(within)
        ourswin.append(right)
        
results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
results["Basewin_prob"] = basewin
results["Draw_prob"] = draw
results["Ourswin_prob"] = ourswin
results
# Out:
# 102
# ========== Average ==========
# SPLGL_0.1: 0.032499999999999994
# SPLGL_0.3: 0.411687843137255
# SPLGL_0.5: 0.8046794117647058
# SPLGL_0.7: 0.8086470588235293
# SPLGL_0.9: 0.8086990196078432
# ==================================== Probability ====================================
# P(SPLGL_0.1 > SPLGL_0.9) = 0.0, P(rope) = 0.0, P(SPLGL_0.9 > SPLGL_0.1) = 1.0
# P(SPLGL_0.3 > SPLGL_0.9) = 0.0, P(rope) = 0.0, P(SPLGL_0.9 > SPLGL_0.3) = 1.0
# P(SPLGL_0.5 > SPLGL_0.9) = 0.0, P(rope) = 0.99904, P(SPLGL_0.9 > SPLGL_0.5) = 0.00096
# P(SPLGL_0.7 > SPLGL_0.9) = 4e-05, P(rope) = 0.99994, P(SPLGL_0.9 > SPLGL_0.7) = 2e-05
#     Baseline       Ours  Basewin_prob  Draw_prob  Ourswin_prob
# 0  SPLGL_0.1  SPLGL_0.9       0.00000    0.00000       1.00000
# 1  SPLGL_0.3  SPLGL_0.9       0.00000    0.00000       1.00000
# 2  SPLGL_0.5  SPLGL_0.9       0.00000    0.99904       0.00096
# 3  SPLGL_0.7  SPLGL_0.9       0.00004    0.99994       0.00002

# %%
# r=0.01 -> 0.9 is chosen
# r=0.005-> 0.9 is chosen
# 4=0.001-> 0.9 is chosen

# %%
# SPLBL
df_ba = df[df['Metrics'] == 'B_Acc']
df_ba = df_ba.drop('Dataset', axis=1)
df_ba = df_ba.reset_index(drop=True)
df_splbl = df_ba.iloc[:,36:41].astype(float)
print(len(df_splbl))

# Average
print("==========", "Average", "==========")
print("SPLBL_0.1:",np.mean(df_splbl.iloc[:,0]))
print("SPLBL_0.3:",np.mean(df_splbl.iloc[:,1]))
print("SPLBL_0.5:",np.mean(df_splbl.iloc[:,2]))
print("SPLBL_0.7:",np.mean(df_splbl.iloc[:,3]))
print("SPLBL_0.9:",np.mean(df_splbl.iloc[:,4]))

# Bayesian Sign Test
print("============"*3, "Probability", "============"*3)
rope = r
baselines = ['SPLBL_0.1','SPLBL_0.3','SPLBL_0.5','SPLBL_0.7']
ours = ['SPLBL_0.9']
dfs = [df_splbl]

comp = []
basewin = []
draw = []
ourswin = []
z = 0
for i in range(len(ours)):
    for j in range(len(baselines)):
#         print(z)
        names = (baselines[j],ours[i])
#         print(names)
        comp.append(names)
        X = np.array(dfs[i][[baselines[j],ours[i]]])
        left, within, right = bt.signtest(X, rope=rope, verbose=True, names=names)
#         print(left, within, right)
        basewin.append(left)
        draw.append(within)
        ourswin.append(right)
        
results = pd.DataFrame(comp, columns = ["Baseline","Ours"])
results["Basewin_prob"] = basewin
results["Draw_prob"] = draw
results["Ourswin_prob"] = ourswin
results
# Out:
# 102
# ========== Average ==========
# SPLBL_0.1: 0.5
# SPLBL_0.3: 0.5604294117647058
# SPLBL_0.5: 0.6684705882352943
# SPLBL_0.7: 0.8022019607843137
# SPLBL_0.9: 0.8144088235294119
# ==================================== Probability ====================================
# P(SPLBL_0.1 > SPLBL_0.9) = 0.0, P(rope) = 0.0, P(SPLBL_0.9 > SPLBL_0.1) = 1.0
# P(SPLBL_0.3 > SPLBL_0.9) = 0.0, P(rope) = 0.0, P(SPLBL_0.9 > SPLBL_0.3) = 1.0
# P(SPLBL_0.5 > SPLBL_0.9) = 0.0, P(rope) = 0.0, P(SPLBL_0.9 > SPLBL_0.5) = 1.0
# P(SPLBL_0.7 > SPLBL_0.9) = 0.0, P(rope) = 0.66334, P(SPLBL_0.9 > SPLBL_0.7) = 0.33666
#     Baseline       Ours  Basewin_prob  Draw_prob  Ourswin_prob
# 0  SPLBL_0.1  SPLBL_0.9           0.0    0.00000       1.00000
# 1  SPLBL_0.3  SPLBL_0.9           0.0    0.00000       1.00000
# 2  SPLBL_0.5  SPLBL_0.9           0.0    0.00000       1.00000
# 3  SPLBL_0.7  SPLBL_0.9           0.0    0.66334       0.33666

# %%
# r=0.01 -> 0.9 is chosen
# r=0.005-> 0.9 is chosen
# 4=0.001-> 0.9 is chosen
