# %% [markdown]
# ## Analaysis of results

# %%
import bayesiantests as bt
import matplotlib.pyplot as plt

#https://matplotlib.org/stable/gallery/lines_bars_and_markers/horizontal_barchart_distribution.html
def stacked_bar(results, category_names):
    """
    Parameters
    ----------
    results : dict
        A mapping from question labels to a list of answers per category.
        It is assumed all lists contain the same number of entries and that
        it matches the length of *category_names*.
    category_names : list of str
        The category labels.
    """
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.colormaps['RdYlGn'](
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, label_type='center', color=text_color)
    ax.legend(ncols=len(category_names), bbox_to_anchor=(0, 1),
              loc='upper left', fontsize='small')

    return fig, ax

# %% [markdown]
# # Robustness Results (L=30, r = f1/gm/ba(0.7/0.3/0.1))

# %%
# noise = 0 (0%)
import pandas as pd
import numpy as np
df = pd.read_csv('[REV-robustness]5CV_MLP(AllTypes_1Repeat)_noise_0.csv')
df.rename(columns={'Unnamed: 0':'Metrics'}, inplace=True)
df

# %%
# F1
df_f1 = df[df['Metrics'] == 'F1']
df_f1 = df_f1.drop('Dataset', axis=1)
df_f1 = df_f1.reset_index(drop=True)
df_f1 = pd.concat([df_f1.iloc[:,1:4], df_f1.iloc[:,4:6]], axis=1)
df_f1 = df_f1.astype(float)
df_f1_n0 = df_f1

# Gmean
df_gm = df[df['Metrics'] == 'Gmean']
df_gm = df_gm.drop('Dataset', axis=1)
df_gm = df_gm.reset_index(drop=True)
df_gm = pd.concat([df_gm.iloc[:,1:4], df_gm.iloc[:,6:8]], axis=1)
df_gm = df_gm.astype(float)
df_gm_n0 = df_gm

# B_Accuracy
df_ba = df[df['Metrics'] == 'B_Acc']
df_ba = df_ba.drop('Dataset', axis=1)
df_ba = df_ba.reset_index(drop=True)
df_ba = pd.concat([df_ba.iloc[:,1:4], df_ba.iloc[:,8:10]], axis=1)
df_ba = df_ba.astype(float)
df_ba_n0 = df_ba
df_ba_n0

# %%
# noise = 0.1 (10%)
import pandas as pd
import numpy as np
df = pd.read_csv('[REV-robustness]5CV_MLP(AllTypes_1Repeat)_noise_1.csv')
df.rename(columns={'Unnamed: 0':'Metrics'}, inplace=True)
df

# %%
# F1
df_f1 = df[df['Metrics'] == 'F1']
df_f1 = df_f1.drop('Dataset', axis=1)
df_f1 = df_f1.reset_index(drop=True)
df_f1 = pd.concat([df_f1.iloc[:,1:4], df_f1.iloc[:,4:6]], axis=1)
df_f1 = df_f1.astype(float)
df_f1_n1 = df_f1

# Gmean
df_gm = df[df['Metrics'] == 'Gmean']
df_gm = df_gm.drop('Dataset', axis=1)
df_gm = df_gm.reset_index(drop=True)
df_gm = pd.concat([df_gm.iloc[:,1:4], df_gm.iloc[:,6:8]], axis=1)
df_gm = df_gm.astype(float)
df_gm_n1 = df_gm

# B_Accuracy
df_ba = df[df['Metrics'] == 'B_Acc']
df_ba = df_ba.drop('Dataset', axis=1)
df_ba = df_ba.reset_index(drop=True)
df_ba = pd.concat([df_ba.iloc[:,1:4], df_ba.iloc[:,8:10]], axis=1)
df_ba = df_ba.astype(float)
df_ba_n1 = df_ba
df_ba_n1

# %%
# noise = 0.2 (20%)
import pandas as pd
import numpy as np
df = pd.read_csv('[REV-robustness]5CV_MLP(AllTypes_1Repeat)_noise_2.csv')
df.rename(columns={'Unnamed: 0':'Metrics'}, inplace=True)
df

# %%
# F1
df_f1 = df[df['Metrics'] == 'F1']
df_f1 = df_f1.drop('Dataset', axis=1)
df_f1 = df_f1.reset_index(drop=True)
df_f1 = pd.concat([df_f1.iloc[:,1:4], df_f1.iloc[:,4:6]], axis=1)
df_f1 = df_f1.astype(float)
df_f1_n2 = df_f1

# Gmean
df_gm = df[df['Metrics'] == 'Gmean']
df_gm = df_gm.drop('Dataset', axis=1)
df_gm = df_gm.reset_index(drop=True)
df_gm = pd.concat([df_gm.iloc[:,1:4], df_gm.iloc[:,6:8]], axis=1)
df_gm = df_gm.astype(float)
df_gm_n2 = df_gm

# B_Accuracy
df_ba = df[df['Metrics'] == 'B_Acc']
df_ba = df_ba.drop('Dataset', axis=1)
df_ba = df_ba.reset_index(drop=True)
df_ba = pd.concat([df_ba.iloc[:,1:4], df_ba.iloc[:,8:10]], axis=1)
df_ba = df_ba.astype(float)
df_ba_n2 = df_ba
df_ba_n2

# %%
# noise = 0.3 (30%)
import pandas as pd
import numpy as np
df = pd.read_csv('[REV-robustness]5CV_MLP(AllTypes_1Repeat)_noise_3.csv')
df.rename(columns={'Unnamed: 0':'Metrics'}, inplace=True)
df

# %%
# F1
df_f1 = df[df['Metrics'] == 'F1']
df_f1 = df_f1.drop('Dataset', axis=1)
df_f1 = df_f1.reset_index(drop=True)
df_f1 = pd.concat([df_f1.iloc[:,1:4], df_f1.iloc[:,4:6]], axis=1)
df_f1 = df_f1.astype(float)
df_f1_n3 = df_f1

# Gmean
df_gm = df[df['Metrics'] == 'Gmean']
df_gm = df_gm.drop('Dataset', axis=1)
df_gm = df_gm.reset_index(drop=True)
df_gm = pd.concat([df_gm.iloc[:,1:4], df_gm.iloc[:,6:8]], axis=1)
df_gm = df_gm.astype(float)
df_gm_n3 = df_gm

# B_Accuracy
df_ba = df[df['Metrics'] == 'B_Acc']
df_ba = df_ba.drop('Dataset', axis=1)
df_ba = df_ba.reset_index(drop=True)
df_ba = pd.concat([df_ba.iloc[:,1:4], df_ba.iloc[:,8:10]], axis=1)
df_ba = df_ba.astype(float)
df_ba_n3 = df_ba
df_ba_n3

# %% [markdown]
# # F1

# %%
df_f1_n0

# %%
df_f1_n1

# %%
df_f1_n2

# %%
df_f1_n3

# %%
f1_n0_mean = [np.mean(df_f1_n0.iloc[:,0]), np.mean(df_f1_n0.iloc[:,1]), np.mean(df_f1_n0.iloc[:,2]), np.mean(df_f1_n0.iloc[:,3]), np.mean(df_f1_n0.iloc[:,4])]
f1_n0_mean

# %%
f1_n1_mean = [np.mean(df_f1_n1.iloc[:,0]), np.mean(df_f1_n1.iloc[:,1]), np.mean(df_f1_n1.iloc[:,2]), np.mean(df_f1_n1.iloc[:,3]), np.mean(df_f1_n1.iloc[:,4])]
f1_n1_mean

# %%
f1_n2_mean = [np.mean(df_f1_n2.iloc[:,0]), np.mean(df_f1_n2.iloc[:,1]), np.mean(df_f1_n2.iloc[:,2]), np.mean(df_f1_n2.iloc[:,3]), np.mean(df_f1_n2.iloc[:,4])]
f1_n2_mean

# %%
f1_n3_mean = [np.mean(df_f1_n3.iloc[:,0]), np.mean(df_f1_n3.iloc[:,1]), np.mean(df_f1_n3.iloc[:,2]), np.mean(df_f1_n3.iloc[:,3]), np.mean(df_f1_n3.iloc[:,4])]
f1_n3_mean

# %%
f1_mean = np.array([f1_n0_mean, f1_n1_mean, f1_n2_mean, f1_n3_mean])
f1_mean

# %%
# plt.rcParams["figure.figsize"] = [5, 3]
plt.rcParams["figure.dpi"] = 200
plt.rcParams['axes.titlesize'] = 20  
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['axes.labelsize'] = 20  
plt.rcParams['font.size'] = 15

import numpy as np
import matplotlib.pyplot as plt

data = f1_mean

# X-axis: row indices
x = np.arange(data.shape[0])  # [0, 1, 2, 3]

# Labels
columns = ['MSE', 'BCE', 'WBCE', 'AnyLoss_org', 'AnyLoss']
rows = ['0%', '10%', '20%', '30%']

# X-axis positions
x = np.arange(len(rows))

# Plot each column as a separate line
for i, col in enumerate(columns):
    plt.plot(x, data[:, i], marker='o', label=col)

# Label setup
plt.xticks(x, rows)
plt.xlabel('Noise Level')
plt.ylabel('Score')
plt.title('Performance with Noise (F1)')
plt.legend(loc='upper right', fontsize='x-small')
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.3, 0.8)
plt.tight_layout()
plt.show()

# %%
# chatgpt
import pandas as pd

# df0, df10, df20, df30 must already be loaded as DataFrames
# with columns: ["MSE", "BCE", "WBCE", "AnyLossOrig", "AnyLoss"]

losses = ["MSE", "BCE", "WBCE", "AnyLoss_org", "AnyLoss"]

# 1. Compute average F1 for each noise level
avg0 = df_f1_n0.mean()
avg10 = df_f1_n1.mean()
avg20 = df_f1_n2.mean()
avg30 = df_f1_n3.mean()

avg_results = pd.DataFrame({
    "0%":   avg0,
    "10%":  avg10,
    "20%":  avg20,
    "30%":  avg30
})

print("Average F1 for each loss at each noise level:")
print(avg_results)
print("\n")


# 2. Compute relative degradation for each loss
# degradation = (F1_clean - F1_noisy) / F1_clean
degradation_10 = (avg0 - avg10) / avg0
degradation_20 = (avg0 - avg20) / avg0
degradation_30 = (avg0 - avg30) / avg0

degradation_results = pd.DataFrame({
    "10%": degradation_10,
    "20%": degradation_20,
    "30%": degradation_30
})

print("Relative degradation for each loss:")
print(degradation_results)
print("\n")


# 3. (Optional) Per-dataset degradation (useful for wins or plots)
per_dataset_degradation_10 = (df_f1_n0 - df_f1_n1).div(df_f1_n0)
per_dataset_degradation_20 = (df_f1_n0 - df_f1_n2).div(df_f1_n0)
per_dataset_degradation_30 = (df_f1_n0 - df_f1_n3).div(df_f1_n0)

# Example: print first few rows
print("Per-dataset degradation at 10% noise (first 5 rows):")
print(per_dataset_degradation_10.head())

# %% [markdown]
# # GM

# %%
gm_n0_mean = [np.mean(df_gm_n0.iloc[:,0]), np.mean(df_gm_n0.iloc[:,1]), np.mean(df_gm_n0.iloc[:,2]), np.mean(df_gm_n0.iloc[:,3]), np.mean(df_gm_n0.iloc[:,4])]
gm_n0_mean

# %%
gm_n1_mean = [np.mean(df_gm_n1.iloc[:,0]), np.mean(df_gm_n1.iloc[:,1]), np.mean(df_gm_n1.iloc[:,2]), np.mean(df_gm_n1.iloc[:,3]), np.mean(df_gm_n1.iloc[:,4])]
gm_n1_mean

# %%
gm_n2_mean = [np.mean(df_gm_n2.iloc[:,0]), np.mean(df_gm_n2.iloc[:,1]), np.mean(df_gm_n2.iloc[:,2]), np.mean(df_gm_n2.iloc[:,3]), np.mean(df_gm_n2.iloc[:,4])]
gm_n2_mean

# %%
gm_n3_mean = [np.mean(df_gm_n3.iloc[:,0]), np.mean(df_gm_n3.iloc[:,1]), np.mean(df_gm_n3.iloc[:,2]), np.mean(df_gm_n3.iloc[:,3]), np.mean(df_gm_n3.iloc[:,4])]
gm_n3_mean

# %%
gm_mean = np.array([gm_n0_mean, gm_n1_mean, gm_n2_mean, gm_n3_mean])
gm_mean

# %%
# plt.rcParams["figure.figsize"] = [5, 3]
plt.rcParams["figure.dpi"] = 200
plt.rcParams['axes.titlesize'] = 20  
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['axes.labelsize'] = 20  
plt.rcParams['font.size'] = 15

import numpy as np
import matplotlib.pyplot as plt

data = gm_mean

# X-axis: row indices
x = np.arange(data.shape[0])  # [0, 1, 2, 3]

# Labels
columns = ['MSE', 'BCE', 'WBCE', 'AnyLoss_org', 'AnyLoss']
rows = ['0%', '10%', '20%', '30%']

# X-axis positions
x = np.arange(len(rows))

# Plot each column as a separate line
for i, col in enumerate(columns):
    plt.plot(x, data[:, i], marker='o', label=col)

# Label setup
plt.xticks(x, rows)
plt.xlabel('Noise Level')
plt.ylabel('Score')
plt.title('Performance with Noise (GM)')
plt.legend(loc='upper right', fontsize='x-small')
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.5, 1.0)
plt.tight_layout()
plt.show()

# %%
# chatgpt
import pandas as pd

# df0, df10, df20, df30 must already be loaded as DataFrames
# with columns: ["MSE", "BCE", "WBCE", "AnyLossOrig", "AnyLoss"]

losses = ["MSE", "BCE", "WBCE", "AnyLoss_org", "AnyLoss"]

# 1. Compute average F1 for each noise level
avg0 = df_gm_n0.mean()
avg10 = df_gm_n1.mean()
avg20 = df_gm_n2.mean()
avg30 = df_gm_n3.mean()

avg_results = pd.DataFrame({
    "0%":   avg0,
    "10%":  avg10,
    "20%":  avg20,
    "30%":  avg30
})

print("Average GM for each loss at each noise level:")
print(avg_results)
print("\n")


# 2. Compute relative degradation for each loss
# degradation = (F1_clean - F1_noisy) / F1_clean
degradation_10 = (avg0 - avg10) / avg0
degradation_20 = (avg0 - avg20) / avg0
degradation_30 = (avg0 - avg30) / avg0

degradation_results = pd.DataFrame({
    "10%": degradation_10,
    "20%": degradation_20,
    "30%": degradation_30
})

print("Relative degradation for each loss:")
print(degradation_results)
print("\n")


# 3. (Optional) Per-dataset degradation (useful for wins or plots)
per_dataset_degradation_10 = (df_gm_n0 - df_gm_n1).div(df_gm_n0)
per_dataset_degradation_20 = (df_gm_n0 - df_gm_n2).div(df_gm_n0)
per_dataset_degradation_30 = (df_gm_n0 - df_gm_n3).div(df_gm_n0)

# Example: print first few rows
print("Per-dataset degradation at 10% noise (first 5 rows):")
print(per_dataset_degradation_10.head())

# %% [markdown]
# # BA

# %%
ba_n0_mean = [np.mean(df_ba_n0.iloc[:,0]), np.mean(df_ba_n0.iloc[:,1]), np.mean(df_ba_n0.iloc[:,2]), np.mean(df_ba_n0.iloc[:,3]), np.mean(df_ba_n0.iloc[:,4])]
ba_n0_mean

# %%
ba_n1_mean = [np.mean(df_ba_n1.iloc[:,0]), np.mean(df_ba_n1.iloc[:,1]), np.mean(df_ba_n1.iloc[:,2]), np.mean(df_ba_n1.iloc[:,3]), np.mean(df_ba_n1.iloc[:,4])]
ba_n1_mean

# %%
ba_n2_mean = [np.mean(df_ba_n2.iloc[:,0]), np.mean(df_ba_n2.iloc[:,1]), np.mean(df_ba_n2.iloc[:,2]), np.mean(df_ba_n2.iloc[:,3]), np.mean(df_ba_n2.iloc[:,4])]
ba_n2_mean

# %%
ba_n3_mean = [np.mean(df_ba_n3.iloc[:,0]), np.mean(df_ba_n3.iloc[:,1]), np.mean(df_ba_n3.iloc[:,2]), np.mean(df_ba_n3.iloc[:,3]), np.mean(df_ba_n3.iloc[:,4])]
ba_n3_mean

# %%
ba_mean = np.array([ba_n0_mean, ba_n1_mean, ba_n2_mean, ba_n3_mean])
ba_mean

# %%
# plt.rcParams["figure.figsize"] = [5, 3]
plt.rcParams["figure.dpi"] = 200
plt.rcParams['axes.titlesize'] = 20  
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['axes.labelsize'] = 20  
plt.rcParams['font.size'] = 15

import numpy as np
import matplotlib.pyplot as plt

data = ba_mean

# X-axis: row indices
x = np.arange(data.shape[0])  # [0, 1, 2, 3]

# Labels
columns = ['MSE', 'BCE', 'WBCE', 'AnyLoss_org', 'AnyLoss']
rows = ['0%', '10%', '20%', '30%']

# X-axis positions
x = np.arange(len(rows))

# Plot each column as a separate line
for i, col in enumerate(columns):
    plt.plot(x, data[:, i], marker='o', label=col)

# Label setup
plt.xticks(x, rows)
plt.xlabel('Noise Level')
plt.ylabel('Score')
plt.title('Performance with Noise (BA)')
plt.legend(loc='upper right', fontsize='x-small')
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0.5, 1.0)
plt.tight_layout()
plt.show()

# %%
# chatgpt
import pandas as pd

# df0, df10, df20, df30 must already be loaded as DataFrames
# with columns: ["MSE", "BCE", "WBCE", "AnyLossOrig", "AnyLoss"]

losses = ["MSE", "BCE", "WBCE", "AnyLoss_org", "AnyLoss"]

# 1. Compute average F1 for each noise level
avg0 = df_ba_n0.mean()
avg10 = df_ba_n1.mean()
avg20 = df_ba_n2.mean()
avg30 = df_ba_n3.mean()

avg_results = pd.DataFrame({
    "0%":   avg0,
    "10%":  avg10,
    "20%":  avg20,
    "30%":  avg30
})

print("Average BA for each loss at each noise level:")
print(avg_results)
print("\n")


# 2. Compute relative degradation for each loss
# degradation = (F1_clean - F1_noisy) / F1_clean
degradation_10 = (avg0 - avg10) / avg0
degradation_20 = (avg0 - avg20) / avg0
degradation_30 = (avg0 - avg30) / avg0

degradation_results = pd.DataFrame({
    "10%": degradation_10,
    "20%": degradation_20,
    "30%": degradation_30
})

print("Relative degradation for each loss:")
print(degradation_results)
print("\n")


# 3. (Optional) Per-dataset degradation (useful for wins or plots)
per_dataset_degradation_10 = (df_ba_n0 - df_ba_n1).div(df_ba_n0)
per_dataset_degradation_20 = (df_ba_n0 - df_ba_n2).div(df_ba_n0)
per_dataset_degradation_30 = (df_ba_n0 - df_ba_n3).div(df_ba_n0)

# Example: print first few rows
print("Per-dataset degradation at 10% noise (first 5 rows):")
print(per_dataset_degradation_10.head())
